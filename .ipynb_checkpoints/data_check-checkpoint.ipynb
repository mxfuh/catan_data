# %%
import numpy as np
import pandas as pd
import streamlit as st
import plotly.express as px
import plotly.graph_objects as go# Get unique years and players
import matplotlib.pyplot as plt

from catan_functions import fit_excel_into_data
from catan_functions import create_hover_data

import re

# %%
data = fit_excel_into_data("catan_data.xlsx")

# resource list
resources = []
for rescol in [col for col in data if "share_" in col]:
    resources.append(rescol[6:])
resources
# Out:
# C:\Users\maxfu\AppData\Local\Programs\Python\Python313\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# C:\Users\maxfu\AppData\Local\Programs\Python\Python313\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# ['wood', 'clay', 'sheep', 'grain', 'ore', 'paper', 'coin', 'fabric']

# %%
data[["place"] + [col for col in data if "p_sum_" in col] + [col for col in data if "share_" in col]].groupby(["place"]).agg("mean")
# Out:
#        p_sum_wood  p_sum_clay  p_sum_sheep  p_sum_grain  p_sum_ore  \
# place
# 1        4.947368    4.631579     4.536842     5.400000   4.178947
# 2        4.957895    5.273684     3.936842     7.000000   3.778947
# 3        4.484211    5.336842     4.568421     6.421053   3.863158
#
#        p_sum_paper  p_sum_coin  p_sum_fabric  share_wood  share_clay  \
# place
# 1         3.000000    2.252632      2.568421    0.345375    0.312951
# 2         2.800000    1.652632      2.189474    0.351326    0.337268
# 3         2.463158    1.631579      2.578947    0.303300    0.349781
#
#        share_sheep  share_grain  share_ore  share_paper  share_coin  \
# place
# 1         0.361604     0.307864   0.351103     0.387203    0.407775
# 2         0.299418     0.364455   0.332934     0.342019    0.278442
# 3         0.338978     0.327681   0.315963     0.270778    0.313783
#
#        share_fabric
# place
# 1          0.364987
# 2          0.285281
# 3          0.349732

# %%
data[["player","season","score"]].groupby(["season","player"]).agg(["sum","mean"])
# Out:
#               score
#                 sum       mean
# season player
# 2022   JHC      307  10.233333
#        MF       254   8.466667
#        PF       314  10.466667
# 2023   JHC      210   9.545455
#        MF       178   8.090909
#        PF       222  10.090909
# 2024   JHC      444   9.866667
#        MF       432        9.6
#        PF       434   9.644444

# %%
# %matplotlib inline

histcol = "share_wood"
bincalc = int(data[histcol].max() * 50) if data[histcol].dtype==float else int(data[histcol].max())

# Option 2: Using the plot method
data[histcol].plot(kind='hist', bins=bincalc, edgecolor='black')
plt.xlabel(histcol)
plt.ylabel("Frequency")
plt.title(f"Distribution of {histcol}")
plt.show()

# %%
df_p = data[["season", "player"] + [col for col in data if "p_sum_" in col]].groupby(["season", "player"]).mean()
df_p
# Out:
#                p_sum_wood  p_sum_clay  p_sum_sheep  p_sum_grain  p_sum_ore  \
# season player
# 2022   JHC       5.310345    4.793103     4.586207     5.379310   4.103448
#        MF        5.758621    5.068966     4.068966     5.689655   3.310345
#        PF        4.724138    4.172414     4.448276     6.241379   3.724138
# 2023   JHC       5.571429    5.666667     3.047619     7.666667   3.523810
#        MF        4.333333    4.761905     5.333333     5.523810   3.714286
#        PF        4.714286    5.095238     4.190476     5.952381   4.523810
# 2024   JHC       4.222222    7.133333     3.622222     7.222222   4.200000
#        MF        4.377778    4.488889     4.400000     6.911111   3.755556
#        PF        4.777778    4.266667     5.200000     5.511111   4.333333
#
#                p_sum_paper  p_sum_coin  p_sum_fabric
# season player
# 2022   JHC        3.482759    1.344828      2.517241
#        MF         4.068966    0.965517      1.965517
#        PF         3.586207    1.793103      2.689655
# 2023   JHC        3.190476    1.380952      2.000000
#        MF         2.571429    1.952381      2.476190
#        PF         2.285714    1.857143      2.285714
# 2024   JHC        1.577778    2.088889      2.200000
#        MF         2.288889    2.133333      2.866667
#        PF         2.644444    2.400000      2.644444

# %%
import streamlit as st

# Style the DataFrame with a green-to-red gradient
styled_df = df_p.style.background_gradient(cmap='RdYlGn')
#st.write(styled_df)
styled_df
# Out:
# <style type="text/css">
# #T_b0323_row0_col0 {
#   background-color: #a0d669;
#   color: #000000;
# }
# #T_b0323_row0_col1 {
#   background-color: #f57245;
#   color: #f1f1f1;
# }
# #T_b0323_row0_col2 {
#   background-color: #b3df72;
#   color: #000000;
# }
# #T_b0323_row0_col3, #T_b0323_row1_col4, #T_b0323_row1_col6, #T_b0323_row1_col7, #T_b0323_row2_col1, #T_b0323_row3_col2, #T_b0323_row6_col0, #T_b0323_row6_col5 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_b0323_row0_col4 {
#   background-color: #bde379;
#   color: #000000;
# }
# #T_b0323_row0_col5 {
#   background-color: #7dc765;
#   color: #000000;
# }
# #T_b0323_row0_col6 {
#   background-color: #fa9656;
#   color: #000000;
# }
# #T_b0323_row0_col7, #T_b0323_row2_col2 {
#   background-color: #d3ec87;
#   color: #000000;
# }
# #T_b0323_row1_col0, #T_b0323_row1_col5, #T_b0323_row3_col3, #T_b0323_row4_col2, #T_b0323_row5_col4, #T_b0323_row6_col1, #T_b0323_row7_col7, #T_b0323_row8_col6 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_b0323_row1_col1 {
#   background-color: #fdaf62;
#   color: #000000;
# }
# #T_b0323_row1_col2 {
#   background-color: #feefa3;
#   color: #000000;
# }
# #T_b0323_row1_col3 {
#   background-color: #e14430;
#   color: #f1f1f1;
# }
# #T_b0323_row2_col0 {
#   background-color: #fdbb6c;
#   color: #000000;
# }
# #T_b0323_row2_col3 {
#   background-color: #fed481;
#   color: #000000;
# }
# #T_b0323_row2_col4 {
#   background-color: #fdc372;
#   color: #000000;
# }
# #T_b0323_row2_col5, #T_b0323_row6_col3 {
#   background-color: #60ba62;
#   color: #f1f1f1;
# }
# #T_b0323_row2_col6 {
#   background-color: #e2f397;
#   color: #000000;
# }
# #T_b0323_row2_col7 {
#   background-color: #63bc62;
#   color: #f1f1f1;
# }
# #T_b0323_row3_col0 {
#   background-color: #2aa054;
#   color: #f1f1f1;
# }
# #T_b0323_row3_col1 {
#   background-color: #fdfebc;
#   color: #000000;
# }
# #T_b0323_row3_col4 {
#   background-color: #ed5f3c;
#   color: #f1f1f1;
# }
# #T_b0323_row3_col5 {
#   background-color: #c1e57b;
#   color: #000000;
# }
# #T_b0323_row3_col6 {
#   background-color: #fca85e;
#   color: #000000;
# }
# #T_b0323_row3_col7 {
#   background-color: #b71126;
#   color: #f1f1f1;
# }
# #T_b0323_row4_col0 {
#   background-color: #c82227;
#   color: #f1f1f1;
# }
# #T_b0323_row4_col1 {
#   background-color: #f36b42;
#   color: #f1f1f1;
# }
# #T_b0323_row4_col3 {
#   background-color: #c41e27;
#   color: #f1f1f1;
# }
# #T_b0323_row4_col4 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_b0323_row4_col5 {
#   background-color: #fee08b;
#   color: #000000;
# }
# #T_b0323_row4_col6 {
#   background-color: #abdb6d;
#   color: #000000;
# }
# #T_b0323_row4_col7 {
#   background-color: #e5f49b;
#   color: #000000;
# }
# #T_b0323_row5_col0 {
#   background-color: #fdb768;
#   color: #000000;
# }
# #T_b0323_row5_col1 {
#   background-color: #fdb365;
#   color: #000000;
# }
# #T_b0323_row5_col2 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_b0323_row5_col3, #T_b0323_row6_col2 {
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_b0323_row5_col5 {
#   background-color: #fba35c;
#   color: #000000;
# }
# #T_b0323_row5_col6 {
#   background-color: #cdea83;
#   color: #000000;
# }
# #T_b0323_row5_col7 {
#   background-color: #fec877;
#   color: #000000;
# }
# #T_b0323_row6_col4 {
#   background-color: #91d068;
#   color: #000000;
# }
# #T_b0323_row6_col6 {
#   background-color: #70c164;
#   color: #000000;
# }
# #T_b0323_row6_col7 {
#   background-color: #f99355;
#   color: #000000;
# }
# #T_b0323_row7_col0 {
#   background-color: #d62f27;
#   color: #f1f1f1;
# }
# #T_b0323_row7_col1 {
#   background-color: #d93429;
#   color: #f1f1f1;
# }
# #T_b0323_row7_col2 {
#   background-color: #dcf08f;
#   color: #000000;
# }
# #T_b0323_row7_col3 {
#   background-color: #b5df74;
#   color: #000000;
# }
# #T_b0323_row7_col4 {
#   background-color: #fece7c;
#   color: #000000;
# }
# #T_b0323_row7_col5 {
#   background-color: #fca55d;
#   color: #000000;
# }
# #T_b0323_row7_col6 {
#   background-color: #5ab760;
#   color: #f1f1f1;
# }
# #T_b0323_row8_col0 {
#   background-color: #fecc7b;
#   color: #000000;
# }
# #T_b0323_row8_col1 {
#   background-color: #b50f26;
#   color: #f1f1f1;
# }
# #T_b0323_row8_col2 {
#   background-color: #0e8245;
#   color: #f1f1f1;
# }
# #T_b0323_row8_col3 {
#   background-color: #c01a27;
#   color: #f1f1f1;
# }
# #T_b0323_row8_col4 {
#   background-color: #45ad5b;
#   color: #f1f1f1;
# }
# #T_b0323_row8_col5 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_b0323_row8_col7 {
#   background-color: #84ca66;
#   color: #000000;
# }
# </style>
# <table id="T_b0323">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b0323_level0_col0" class="col_heading level0 col0" >p_sum_wood</th>
#       <th id="T_b0323_level0_col1" class="col_heading level0 col1" >p_sum_clay</th>
#       <th id="T_b0323_level0_col2" class="col_heading level0 col2" >p_sum_sheep</th>
#       <th id="T_b0323_level0_col3" class="col_heading level0 col3" >p_sum_grain</th>
#       <th id="T_b0323_level0_col4" class="col_heading level0 col4" >p_sum_ore</th>
#       <th id="T_b0323_level0_col5" class="col_heading level0 col5" >p_sum_paper</th>
#       <th id="T_b0323_level0_col6" class="col_heading level0 col6" >p_sum_coin</th>
#       <th id="T_b0323_level0_col7" class="col_heading level0 col7" >p_sum_fabric</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >season</th>
#       <th class="index_name level1" >player</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b0323_level0_row0" class="row_heading level0 row0" rowspan="3">2022</th>
#       <th id="T_b0323_level1_row0" class="row_heading level1 row0" >JHC</th>
#       <td id="T_b0323_row0_col0" class="data row0 col0" >5.310345</td>
#       <td id="T_b0323_row0_col1" class="data row0 col1" >4.793103</td>
#       <td id="T_b0323_row0_col2" class="data row0 col2" >4.586207</td>
#       <td id="T_b0323_row0_col3" class="data row0 col3" >5.379310</td>
#       <td id="T_b0323_row0_col4" class="data row0 col4" >4.103448</td>
#       <td id="T_b0323_row0_col5" class="data row0 col5" >3.482759</td>
#       <td id="T_b0323_row0_col6" class="data row0 col6" >1.344828</td>
#       <td id="T_b0323_row0_col7" class="data row0 col7" >2.517241</td>
#     </tr>
#     <tr>
#       <th id="T_b0323_level1_row1" class="row_heading level1 row1" >MF</th>
#       <td id="T_b0323_row1_col0" class="data row1 col0" >5.758621</td>
#       <td id="T_b0323_row1_col1" class="data row1 col1" >5.068966</td>
#       <td id="T_b0323_row1_col2" class="data row1 col2" >4.068966</td>
#       <td id="T_b0323_row1_col3" class="data row1 col3" >5.689655</td>
#       <td id="T_b0323_row1_col4" class="data row1 col4" >3.310345</td>
#       <td id="T_b0323_row1_col5" class="data row1 col5" >4.068966</td>
#       <td id="T_b0323_row1_col6" class="data row1 col6" >0.965517</td>
#       <td id="T_b0323_row1_col7" class="data row1 col7" >1.965517</td>
#     </tr>
#     <tr>
#       <th id="T_b0323_level1_row2" class="row_heading level1 row2" >PF</th>
#       <td id="T_b0323_row2_col0" class="data row2 col0" >4.724138</td>
#       <td id="T_b0323_row2_col1" class="data row2 col1" >4.172414</td>
#       <td id="T_b0323_row2_col2" class="data row2 col2" >4.448276</td>
#       <td id="T_b0323_row2_col3" class="data row2 col3" >6.241379</td>
#       <td id="T_b0323_row2_col4" class="data row2 col4" >3.724138</td>
#       <td id="T_b0323_row2_col5" class="data row2 col5" >3.586207</td>
#       <td id="T_b0323_row2_col6" class="data row2 col6" >1.793103</td>
#       <td id="T_b0323_row2_col7" class="data row2 col7" >2.689655</td>
#     </tr>
#     <tr>
#       <th id="T_b0323_level0_row3" class="row_heading level0 row3" rowspan="3">2023</th>
#       <th id="T_b0323_level1_row3" class="row_heading level1 row3" >JHC</th>
#       <td id="T_b0323_row3_col0" class="data row3 col0" >5.571429</td>
#       <td id="T_b0323_row3_col1" class="data row3 col1" >5.666667</td>
#       <td id="T_b0323_row3_col2" class="data row3 col2" >3.047619</td>
#       <td id="T_b0323_row3_co

# %%
df_t
# Out:
#                p_sum_wood  p_sum_clay  p_sum_sheep  p_sum_grain  p_sum_ore  \
# season player
# 2022   JHC          458.0       407.0        380.0        502.0      323.0
#        MF           458.0       407.0        380.0        502.0      323.0
#        PF           458.0       407.0        380.0        502.0      323.0
# 2023   JHC          307.0       326.0        264.0        402.0      247.0
#        MF           307.0       326.0        264.0        402.0      247.0
#        PF           307.0       326.0        264.0        402.0      247.0
# 2024   JHC          602.0       715.0        595.0        884.0      553.0
#        MF           602.0       715.0        595.0        884.0      553.0
#        PF           602.0       715.0        595.0        884.0      553.0
#
#                p_sum_paper  p_sum_coin  p_sum_fabric
# season player
# 2022   JHC           323.0       119.0         208.0
#        MF            323.0       119.0         208.0
#        PF            323.0       119.0         208.0
# 2023   JHC           169.0       109.0         142.0
#        MF            169.0       109.0         142.0
#        PF            169.0       109.0         142.0
# 2024   JHC           293.0       298.0         347.0
#        MF            293.0       298.0         347.0
#        PF            293.0       298.0         347.0

# %%
# Group and aggregate the data
df_p = data[["season", "player"] + [col for col in data if "p_sum_" in col]].groupby(["season", "player"]).sum()
df_t = data[["season", "player"] + [col for col in data if "t_sum_" in col]].groupby(["season", "player"]).sum()

# Rename the columns in df_t to match those in df_p
df_t.rename(columns=lambda col: col.replace("t_sum_", "p_sum_") if "t_sum_" in col else col, inplace=True)

# Now perform elementwise division
ratio_df = df_p / df_t

print(ratio_df)
# Out:
#                p_sum_wood  p_sum_clay  p_sum_sheep  p_sum_grain  p_sum_ore  \
# season player
# 2022   JHC       0.336245    0.341523     0.350000     0.310757   0.368421
#        MF        0.364629    0.361179     0.310526     0.328685   0.297214
#        PF        0.299127    0.297297     0.339474     0.360558   0.334365
# 2023   JHC       0.381107    0.365031     0.242424     0.400498   0.299595
#        MF        0.296417    0.306748     0.424242     0.288557   0.315789
#        PF        0.322476    0.328221     0.333333     0.310945   0.384615
# 2024   JHC       0.315615    0.448951     0.273950     0.367647   0.341772
#        MF        0.327243    0.282517     0.332773     0.351810   0.305606
#        PF        0.357143    0.268531     0.393277     0.280543   0.352622
#
#                p_sum_paper  p_sum_coin  p_sum_fabric
# season player
# 2022   JHC        0.312693    0.327731      0.350962
#        MF         0.365325    0.235294      0.274038
#        PF         0.321981    0.436975      0.375000
# 2023   JHC        0.396450    0.266055      0.295775
#        MF         0.319527    0.376147      0.366197
#        PF         0.284024    0.357798      0.338028
# 2024   JHC        0.242321    0.315436      0.285303
#        MF         0.351536    0.322148      0.371758
#        PF         0.406143    0.362416      0.342939

# %%
df_p_loc = data[["season", "player","loc","score"] + [col for col in data if "p_sum_" in col]].groupby(["season", "player","loc"]).mean()
df_p_loc.style.background_gradient(cmap='RdYlGn')
# Out:
# <style type="text/css">
# #T_ed408_row0_col1, #T_ed408_row4_col1 {
#   background-color: #51b35e;
#   color: #f1f1f1;
# }
# #T_ed408_row0_col2, #T_ed408_row28_col2 {
#   background-color: #bd1726;
#   color: #f1f1f1;
# }
# #T_ed408_row0_col3 {
#   background-color: #9bd469;
#   color: #000000;
# }
# #T_ed408_row0_col4 {
#   background-color: #fffab6;
#   color: #000000;
# }
# #T_ed408_row0_col5, #T_ed408_row7_col6, #T_ed408_row10_col1, #T_ed408_row24_col1, #T_ed408_row28_col5, #T_ed408_row33_col1, #T_ed408_row34_col8, #T_ed408_row35_col5, #T_ed408_row36_col1 {
#   background-color: #f4fab0;
#   color: #000000;
# }
# #T_ed408_row0_col6, #T_ed408_row34_col5 {
#   background-color: #cdea83;
#   color: #000000;
# }
# #T_ed408_row0_col7 {
#   background-color: #f57748;
#   color: #f1f1f1;
# }
# #T_ed408_row0_col8, #T_ed408_row4_col3, #T_ed408_row6_col8, #T_ed408_row14_col5 {
#   background-color: #ebf7a3;
#   color: #000000;
# }
# #T_ed408_row1_col1, #T_ed408_row2_col1, #T_ed408_row14_col1, #T_ed408_row23_col1 {
#   background-color: #a2d76a;
#   color: #000000;
# }
# #T_ed408_row1_col2 {
#   background-color: #f88950;
#   color: #f1f1f1;
# }
# #T_ed408_row1_col3, #T_ed408_row3_col3, #T_ed408_row18_col8, #T_ed408_row25_col8 {
#   background-color: #f7fcb4;
#   color: #000000;
# }
# #T_ed408_row1_col4, #T_ed408_row13_col2, #T_ed408_row29_col4 {
#   background-color: #fed07e;
#   color: #000000;
# }
# #T_ed408_row1_col5, #T_ed408_row32_col5 {
#   background-color: #bbe278;
#   color: #000000;
# }
# #T_ed408_row1_col6, #T_ed408_row4_col4, #T_ed408_row14_col7, #T_ed408_row29_col7, #T_ed408_row36_col6, #T_ed408_row38_col7 {
#   background-color: #fff0a6;
#   color: #000000;
# }
# #T_ed408_row1_col7, #T_ed408_row4_col7, #T_ed408_row30_col1, #T_ed408_row31_col1, #T_ed408_row37_col1 {
#   background-color: #fec877;
#   color: #000000;
# }
# #T_ed408_row1_col8, #T_ed408_row3_col4 {
#   background-color: #feea9b;
#   color: #000000;
# }
# #T_ed408_row2_col2, #T_ed408_row18_col2, #T_ed408_row21_col2, #T_ed408_row31_col2, #T_ed408_row36_col4 {
#   background-color: #e75337;
#   color: #f1f1f1;
# }
# #T_ed408_row2_col3, #T_ed408_row12_col5, #T_ed408_row16_col3, #T_ed408_row30_col3 {
#   background-color: #f2faae;
#   color: #000000;
# }
# #T_ed408_row2_col4, #T_ed408_row23_col4, #T_ed408_row37_col4 {
#   background-color: #fa9656;
#   color: #000000;
# }
# #T_ed408_row2_col5, #T_ed408_row11_col8, #T_ed408_row27_col4 {
#   background-color: #f5fbb2;
#   color: #000000;
# }
# #T_ed408_row2_col6, #T_ed408_row9_col3, #T_ed408_row10_col3, #T_ed408_row16_col7, #T_ed408_row22_col3, #T_ed408_row24_col8, #T_ed408_row37_col8 {
#   background-color: #fee08b;
#   color: #000000;
# }
# #T_ed408_row2_col7, #T_ed408_row25_col2 {
#   background-color: #e14430;
#   color: #f1f1f1;
# }
# #T_ed408_row2_col8, #T_ed408_row8_col8, #T_ed408_row13_col7, #T_ed408_row18_col7, #T_ed408_row27_col1, #T_ed408_row32_col8 {
#   background-color: #d9ef8b;
#   color: #000000;
# }
# #T_ed408_row3_col1 {
#   background-color: #5ab760;
#   color: #f1f1f1;
# }
# #T_ed408_row3_col2 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_ed408_row3_col5, #T_ed408_row11_col3, #T_ed408_row17_col3 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_ed408_row3_col6, #T_ed408_row12_col1 {
#   background-color: #d3ec87;
#   color: #000000;
# }
# #T_ed408_row3_col7, #T_ed408_row11_col7, #T_ed408_row24_col6, #T_ed408_row31_col6 {
#   background-color: #ca2427;
#   color: #f1f1f1;
# }
# #T_ed408_row3_col8 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_ed408_row4_col2 {
#   background-color: #c82227;
#   color: #f1f1f1;
# }
# #T_ed408_row4_col5, #T_ed408_row28_col4 {
#   background-color: #c5e67e;
#   color: #000000;
# }
# #T_ed408_row4_col6, #T_ed408_row6_col6 {
#   background-color: #f8fcb6;
#   color: #000000;
# }
# #T_ed408_row4_col8, #T_ed408_row12_col4, #T_ed408_row19_col6, #T_ed408_row33_col6 {
#   background-color: #fdc171;
#   color: #000000;
# }
# #T_ed408_row5_col1, #T_ed408_row5_col6, #T_ed408_row10_col5, #T_ed408_row13_col3, #T_ed408_row13_col8, #T_ed408_row23_col2, #T_ed408_row23_col7, #T_ed408_row30_col5, #T_ed408_row30_col7, #T_ed408_row31_col4, #T_ed408_row37_col7 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_ed408_row5_col2, #T_ed408_row16_col8, #T_ed408_row22_col7 {
#   background-color: #fdad60;
#   color: #000000;
# }
# #T_ed408_row5_col3 {
#   background-color: #e2f397;
#   color: #000000;
# }
# #T_ed408_row5_col4, #T_ed408_row6_col5, #T_ed408_row16_col1 {
#   background-color: #feec9f;
#   color: #000000;
# }
# #T_ed408_row5_col5, #T_ed408_row5_col7, #T_ed408_row8_col2, #T_ed408_row10_col4, #T_ed408_row13_col1, #T_ed408_row13_col6, #T_ed408_row14_col2, #T_ed408_row16_col6, #T_ed408_row23_col3, #T_ed408_row23_col6, #T_ed408_row23_col8, #T_ed408_row26_col7, #T_ed408_row30_col6, #T_ed408_row32_col6, #T_ed408_row33_col8, #T_ed408_row37_col6 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_ed408_row5_col8, #T_ed408_row8_col7, #T_ed408_row10_col8, #T_ed408_row19_col7, #T_ed408_row21_col7 {
#   background-color: #f46d43;
#   color: #f1f1f1;
# }
# #T_ed408_row6_col1, #T_ed408_row7_col1, #T_ed408_row15_col3, #T_ed408_row32_col3 {
#   background-color: #b7e075;
#   color: #000000;
# }
# #T_ed408_row6_col2 {
#   background-color: #ed5f3c;
#   color: #f1f1f1;
# }
# #T_ed408_row6_col3 {
#   background-color: #cbe982;
#   color: #000000;
# }
# #T_ed408_row6_col4, #T_ed408_row17_col4, #T_ed408_row25_col5 {
#   background-color: #fff2aa;
#   color: #000000;
# }
# #T_ed408_row6_col7 {
#   background-color: #fb9d59;
#   color: #000000;
# }
# #T_ed408_row7_col2 {
#   background-color: #c62027;
#   color: #f1f1f1;
# }
# #T_ed408_row7_col3, #T_ed408_row24_col7, #T_ed408_row26_col5, #T_ed408_row29_col3, #T_ed408_row29_col8, #T_ed408_row33_col3, #T_ed408_row33_col7, #T_ed408_row36_col7 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_ed408_row7_col4 {
#   background-color: #fafdb8;
#   color: #000000;
# }
# #T_ed408_row7_col5, #T_ed408_row8_col4, #T_ed408_row9_col6 {
#   background-color: #d1ec86;
#   color: #000000;
# }
# #T_ed408_row7_col7, #T_ed408_row18_col3, #T_ed408_row32_col7 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_ed408_row7_col8, #T_ed408_row17_col6 {
#   background-color: #fdfebc;
#   color: #000000;
# }
# #T_ed408_row8_col1, #T_ed408_row25_col3 {
#   background-color: #ddf191;
#   color: #000000;
# }
# #T_ed408_row8_col3 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_ed408_row8_col5 {
#   background-color: #e3f399;
#   color: #000000;
# }
# #T_ed408_row8_col6, #T_ed408_row31_col8 {
#   background-color: #bfe47a;
#   color: #000000;
# }
# #T_ed408_row9_col1 {
#   background-color: #33a456;
#   color: #f1f1f1;
# }
# #T_ed408_row9_col2 {
#   background-color: #db382b;
#   color: #f1f1f1;
# }
# #T_ed408_row9_col4 {
#   background-color: #b3df72;
#   color: #000000;
# }
# #T_ed408_row9_col5, #T_ed408_row15_col1, #T_ed408_row19_col3 {
#   background-color: #fff5ae;
#   color: #000000;
# }
# #T_ed408_row9_col7, #T_ed408_row12_col7 {
#   background-color: #fdb365;
#   color: #000000;
# }
# #T_ed408_row9_col8 {
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_ed408_row10_col2 {
#   background-color: #fba05b;
#   color: #000000;
# }
# #T_ed408_row10_col6, #T_ed408_row14_col6, #T_ed408_row17_col8, #T_ed408_row29_col6 {
#   background-color: #fed481;
#   color: #000000;
# }
# #T_ed408_row10_col7 {
#   background-color: #199750;
#   color: #f1f1f1;
# }
# #T_ed408_row11_col1, #T_ed408_row22_col1 {
#   background-color: #69be63;
#   color: #f1f1f1;
# }
# #T_ed408_row11_col2 {
#   background-color: #fcaa5f;
#   color: #000000;
# }
# #T_ed408_row11_col4, #T_ed408_row34_col1 {
#   background-color: #75c465;
#   color: #000000;
# }
# #T_ed408_row11_col5, #T_ed408_row13_col5, #T_ed408_row15_col4, #T_ed408_row31_col5 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_ed408_row11_col6 {
#   background-color: #fdb768;
#   color: #000000;
# }
# #T_ed408_row12_col2, #T_ed408_row13_col4 {
#   background-color: #f57245;
#   color: #f1f1f1;
# }
# #T_ed408_row12_col3, #T_ed408_row19_col5, #T_ed408_row20_col4 {
#   background-color: #c3e67d;
#   color: #000000;
# }
# #T_ed408_row12_col6 {
#   background-color: #fff3ac;
#   color: #000000;
# }
# #T_ed408_row12_col8, #T_ed408_row20_col3 {
#   background-color: #fff1a8;
#   color: #000000;
# }
# #T_ed408_row14_col3 {
#   background-color: #91d068;
#   color: #000000;
# }
# #T_ed408_row14_col4, #T_ed408_row27_col7 {
#   background-col
