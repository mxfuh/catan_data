# %% [markdown]
# # Imports

# %%
excel_file = "catan_data.xlsx"

# %%
import numpy as np
import pandas as pd
import sklearn as skl
import math
import matplotlib as mpl
import statsmodels.api as sm

# %% [markdown]
# # Einlesen und aufbereiten

# %%
# Read data and fix column names.
cols = list(pd.read_excel(excel_file).iloc[0, :])
data = pd.read_excel(excel_file).iloc[1:, :]
data.columns = cols

data["score"] = pd.to_numeric(data["score"], errors = "coerce")
    
# Create additional columns.
data["game_id"] = data["season"] * 100 + data["game"]
data["month"] = pd.to_datetime(data["Session"]).dt.month
    
# Split 'geoloc' into 'latitude' and 'longitude'
data[['latitude', 'longitude']] = data['geoloc'].str.split(', ', expand=True)
data['latitude'] = pd.to_numeric(data['latitude'], errors='coerce')
data['longitude'] = pd.to_numeric(data['longitude'], errors='coerce')
    
    # Generate additional information columns.
resources = []
for colname in [col for col in data if "t_sum" in col]:
    resources.append(colname[6:])  # extract resource name
for resource in resources:
    # Generate total production values (using min_count=1 so that groups with all NaN return NaN).
    data[f"t_sum_{resource}"] = data.groupby(["season", "game"])[f"p_sum_{resource}"].transform(
        lambda x: x.sum(min_count=1)
    )
        
    # Ensure the columns are numeric.
    data[f"p_sum_{resource}"] = pd.to_numeric(data[f"p_sum_{resource}"], errors="coerce")
    data[f"t_sum_{resource}"] = pd.to_numeric(data[f"t_sum_{resource}"], errors="coerce")
        
    # Generate share of production values safely.
    data[f"share_{resource}"] = np.nan  # default to NaN
    mask = data[f"t_sum_{resource}"] != 0
    data.loc[mask, f"share_{resource}"] = (
        data.loc[mask, f"p_sum_{resource}"] / data.loc[mask, f"t_sum_{resource}"]
    )

# "onehot" create new desert cols
for val in data["desert"].unique():
    if pd.isna(val):
        continue
    else:    
        data["desert_"+val] = (data["desert"] == val).astype(int)

# "onehot" create new position cols
for val in data["position"].unique():
    if pd.isna(val):
        continue
    else:    
        data["position_"+val] = (data["position"] == val).astype(int)   

# "onehot" create new player cols
for val in data["player"].unique():
    if pd.isna(val):
        continue
    else:    
        data["player_"+val] = (data["player"] == val).astype(int)   

# std berechnen
data["std_resources"] = data[[col for col in data if "p_sum" in col]].std(axis = 1)        
    
    
# Generate points column.
data["points"] = data["place"].map({1: 2, 2: 1, 3: 0})
    
# Sort by game_id to ensure cumulative sums are in order.
data = data.sort_values("game_id")
    
# Compute cumulative points (overall and year-to-date) in a vectorized manner.
data["points_cum"] = data.groupby("player")["points"].cumsum()
data["points_cum_ytd"] = data.groupby(["season", "player"])["points"].cumsum()



#produktion: split in rohstoff und handelswaren
data["sum_resources"] = data[['p_sum_wood','p_sum_clay','p_sum_sheep',
                          'p_sum_grain','p_sum_ore',]].apply("sum",axis = 1)
data["sum_tradegoods"] = data[["p_sum_paper","p_sum_coin","p_sum_fabric"]].apply("sum",axis = 1)
# Out:
# C:\Users\maxfu\AppData\Local\Programs\Python\Python313\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# C:\Users\maxfu\AppData\Local\Programs\Python\Python313\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %%
[col for col in data 
 if "p_sum" in col
 or "share_" in col
 or "port_" in col
 or "desert_" in col
 or "player_" in col
 or ("sum_" in col and col not in [col for col in data if "t_sum" in col])
 or "std_" in col
] + ["score", "special","place"]
# Out:
# ['p_sum_wood',
#  'p_sum_clay',
#  'p_sum_sheep',
#  'p_sum_grain',
#  'p_sum_ore',
#  'p_sum_paper',
#  'p_sum_coin',
#  'p_sum_fabric',
#  'port_wood',
#  'port_clay',
#  'port_sheep',
#  'port_grain',
#  'port_ore',
#  'port_gen',
#  'prox_port_wood',
#  'prox_port_clay',
#  'prox_port_sheep',
#  'prox_port_grain',
#  'prox_port_ore',
#  'prox_port_gen',
#  'share_wood',
#  'share_clay',
#  'share_sheep',
#  'share_grain',
#  'share_ore',
#  'share_paper',
#  'share_coin',
#  'share_fabric',
#  'desert_center',
#  'desert_outer',
#  'desert_second',
#  'player_PF',
#  'player_MF',
#  'player_JHC',
#  'std_resources',
#  'sum_resources',
#  'sum_tradegoods',
#  'score',
#  'special',
#  'place']

# %% [markdown]
# # Auswertungen

# %% [markdown]
# ## xxv001 - resource share by player

# %%
for value in data["player"].unique():
    data[value] = (data["player"] == value).astype(int)
    
shares = {}
for player in data["player"].unique():
    x = []
    for resource in resources:
        t = data.loc[data[player]==1]["share_"+resource].describe()[["mean","std"]]
        t = pd.DataFrame(t).T.rename(columns = {"mean":"mean_"+player,"std":"std_"+player})
        x.append(t)
    shares[player] = pd.concat(x)

shares = pd.concat(shares.values(),axis = 1)

shares.to_excel("xxv001 - resource shares by player.xlsx")

# %% [markdown]
# ## xxv002 - regression shares

# %%
data[[
     'share_wood',"share_clay",'share_grain','share_ore',"share_sheep",
     'share_paper','share_coin','share_fabric',]]
# Out:
#      share_wood  share_clay  share_grain  share_ore  share_sheep  share_paper  \
# 1      0.250000    0.266667     0.555556   0.384615     0.363636          0.0
# 2      0.625000    0.200000     0.296296   0.230769     0.000000          1.0
# 3      0.125000    0.533333     0.148148   0.384615     0.636364          0.0
# 4      0.166667    0.250000     0.578947   0.230769     0.200000          0.0
# 5      0.277778    0.500000     0.105263   0.538462     0.800000          0.0
# ..          ...         ...          ...        ...          ...          ...
# 355    0.250000    1.000000     0.272727   0.200000     0.400000          0.5
# 357    0.350000    0.000000     0.181818   0.200000     0.600000          0.5
# 359    0.363636    0.428571     0.718750   0.000000     0.142857          0.0
# 358    0.363636    0.000000     0.125000   0.692308     0.285714          1.0
# 360    0.272727    0.571429     0.156250   0.307692     0.571429          0.0
#
#      share_coin  share_fabric
# ...

# %%
X = data[[col for col in data if "p_sum" in col or "share_" in col]]
y = data["score"]

X_scaled = (X - X.mean()) / X.std()

X_scaled = sm.add_constant(X_scaled)
model = sm.OLS(y, X_scaled, missing="drop", hasconst=None).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                  score   R-squared (uncentered):                   0.914
# Model:                            OLS   Adj. R-squared (uncentered):              0.909
# Method:                 Least Squares   F-statistic:                              161.6
# Date:                Fri, 24 Apr 2026   Prob (F-statistic):                   3.28e-119
# Time:                        21:15:03   Log-Likelihood:                         -644.11
# No. Observations:                 258   AIC:                                      1320.
# Df Residuals:                     242   BIC:                                      1377.
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
# z-standardized

X = data[[col for col in data if "p_sum" in col or "share_" in col]]
y = data["score"]

X_scaled = (X - X.mean()) / X.std()

X_scaled = sm.add_constant(X_scaled)
model = sm.OLS(y, X_scaled, missing="drop", hasconst=None).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  score   R-squared:                       0.100
# Model:                            OLS   Adj. R-squared:                  0.040
# Method:                 Least Squares   F-statistic:                     1.674
# Date:                Fri, 24 Apr 2026   Prob (F-statistic):             0.0523
# Time:                        21:16:07   Log-Likelihood:                -638.74
# No. Observations:                 258   AIC:                             1311.
# Df Residuals:                     241   BIC:                             1372.
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## xxv003 - startspieler abhängig von wüstenposition

# %%
data.groupby(["player","position"])["score"].agg("mean")
# Out:
# player  position
# JHC     first        9.180000
#         second       9.717949
#         third        9.935484
# MF      first        8.000000
#         second       8.526316
#         third        9.740000
# PF      first        9.421053
#         second      11.023256
#         third       10.282051
# Name: score, dtype: float64

# %%
data.groupby(["player","place"])["place"].count()
# Out:
# player  place
# JHC     1        39
#         2        44
#         3        37
# MF      1        29
#         2        38
#         3        53
# PF      1        52
#         2        38
#         3        30
# Name: place, dtype: int64

# %% [markdown]
# ## ports

# %%
x = []
for resource in resources:
    if resource not in ["paper","coin","fabric"]:
        tdf = data.loc[df["port_"+resource]==1].copy()
        tres = tdf[["p_sum_"+resource,"score","place"]].copy().rename(columns = {"p_sum_"+resource:"production"})
        tres["resource"] = resource
        x.append(tres)
    
port_res = pd.concat(x)
#display(port_res)

port_res.groupby("resource")[["production","score","place"]].agg(["count","mean"])

#X = port_res[["production"]]
#X = sm.add_constant(X)
#y = port_res["score"]
#model = sm.OLS(y, X,missing = "drop",hasconst=True).fit()
#model.summary()
# Out:
#          production            score            place
#               count       mean count       mean count      mean
# resource
# clay              8   8.750000     8   8.250000     8      2.25
# grain            10  11.000000    10  10.800000    10       1.7
# ore               3   3.666667     3   7.333333     3  2.666667
# sheep             5   7.200000     5  11.400000     5       1.6
# wood              2  11.500000     2  10.000000     2       2.5

# %%
x = []
for resource in resources:
    if resource not in ["paper","coin","fabric"]:
        tdf = data.loc[data["prox_port_"+resource]==1].copy()
        tres = tdf[["p_sum_"+resource,"score","place"]].copy().rename(columns = {"p_sum_"+resource:"production"})
        tres["resource"] = resource
        x.append(tres)
    
prox_port_res = pd.concat(x)
#display(prox_port_res)

prox_port_res.groupby("resource")[["production","score","place"]].agg(["count","mean"])

#X = prox_port_res[["production"]]
#X = sm.add_constant(X)
#y = prox_port_res["score"]
#model = sm.OLS(y, X,missing = "drop",hasconst=True).fit()
#model.summary()
# Out:
#          production           score            place
#               count      mean count       mean count      mean
# resource
# clay             56  5.642857    56  10.928571    56  1.785714
# grain            58  8.344828    58   9.896552    58  1.862069
# ore              41  5.024390    41  10.170732    41  1.853659
# sheep            62  5.209677    62   8.822581    62  2.129032
# wood             53  6.000000    53   9.754717    53  1.886792

# %%
#platzierung nach spieler
for player in df["player"].unique():
    print(player)
    print(df.loc[df[player]==1]["place"].value_counts().sort_index())
# Out:
# PF
# place
# 1    52
# 2    38
# 3    30
# Name: count, dtype: int64
# MF
# place
# 1    29
# 2    38
# 3    53
# Name: count, dtype: int64
# JHC
# place
# 1    39
# 2    44
# 3    37
# Name: count, dtype: int64

# %%
#sieg platzierung nach spieler und location

for location in df["loc"].unique():
    tempdf = df.loc[df["loc"]==location]
    for player in df["player"].unique():
        print(location)
        print(player)
        print(tempdf.loc[tempdf[player]==1]["place"].value_counts(normalize = True).sort_index())
# Out:
# Husum (Memeler Str.)
# PF
# place
# 1    0.452381
# 2    0.333333
# 3    0.214286
# Name: proportion, dtype: float64
# Husum (Memeler Str.)
# MF
# place
# 1    0.214286
# 2    0.309524
# 3    0.476190
# Name: proportion, dtype: float64
# Husum (Memeler Str.)
# JHC
# place
# 1    0.333333
# 2    0.357143
# 3    0.309524
# Name: proportion, dtype: float64
# Hamburg (Kegelhofstr. 29)
# PF
# place
# 1    0.500000
# 2    0.333333
# 3    0.166667
# Name: proportion, dtype: float64
# Hamburg (Kegelhofstr. 29)
# MF
# place
# 1    0.125000
# 2    0.291667
# 3    0.583333
# Name: proportion, dtype: float64
# Hamburg (Kegelhofstr. 29)
# JHC
# place
# 1    0.375
# 2    0.375
# 3    0.250
# Name: proportion, dtype: float64
# Online
# PF
# place
# 1    0.666667
# 3    0.333333
# Name: proportion, dtype: float64
# Online
# MF
# place
# 2    0.333333
# 3    0.666667
# Name: proportion, dtype: float64
# Online
# JHC
# place
# 1    0.333333
# 2    0.666667
# Name: proportion, dtype: float64
# ...

# %%
# Out:
# PF
# 1    15
# 2     9
# 3     6
# Name: place, dtype: int64
# MF
# 1     4
# 2    10
# 3    16
# Name: place, dtype: int64
# JHC
# 1    11
# 2    11
# 3     8
# Name: place, dtype: int64

# %%
data["std_resources"] = data[[col for col in data if "p_sum" in col]].std(axis = 1)

# %%
data["std_resources"].describe()
# Out:
# count    354.000000
# mean       3.460601
# std        1.296603
# min        1.125992
# 25%        2.587746
# 50%        3.292236
# 75%        4.100840
# max       10.176128
# Name: std_resources, dtype: float64

# %%
#relativ ausgeglichene rohstoffwahl: effekt auf siegquote
data.loc[(data["std_resources"]>3)]["score"].mean()
# Out:
# np.float64(9.352941176470589)

# %%
data.loc[(data["std_resources"]>5)]
# Out:
#     season              Session game                        loc  \
# 13    2022  2022-03-19 00:00:00    5       Husum (Memeler Str.)
# 17    2022  2022-03-19 00:00:00    6       Husum (Memeler Str.)
# 32    2022  2022-06-04 00:00:00   11  Hamburg (Kegelhofstr. 29)
# 34    2022  2022-06-04 00:00:00   12  Hamburg (Kegelhofstr. 29)
# 75    2022  2022-11-19 00:00:00   25  Hamburg (Kegelhofstr. 29)
# 90    2022  2022-12-29 00:00:00   30       Husum (Memeler Str.)
# 94    2023  2023-04-04 00:00:00    2        Köln (Nikolausstr.)
# 121   2023  2023-04-10 00:00:00   11       Husum (Memeler Str.)
# 136   2023  2023-10-07 00:00:00   16  Hamburg (Kegelhofstr. 29)
# 164   2024  2024-03-15 00:00:00    3       Husum (Memeler Str.)
# 178   2024  2024-05-24 00:00:00    8       Husum (Memeler Str.)
# 198   2024  2024-05-24 00:00:00   14       Husum (Memeler Str.)
# 197   2024  2024-05-24 00:00:00   14       Husum (Memeler Str.)
# 206   2024  2024-07-24 00:00:00   17                   Frafjord
# ...
